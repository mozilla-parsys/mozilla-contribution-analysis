# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('div.output_text').hide('500')
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('div.output_text').show('500')
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#     $('div.output_text').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# ### Metric Calculations
# First we need to load a connection against the proper ES instance. We use an external module to load credentials from a file that will not be shared. If you want to run this, please use your own credentials, just put them in a file named '.settings' (in the same directory as this notebook) following the example file 'settings.sample'.
#
# To work with **survey results** this notebook expect to find the following files:
# * **UUID's**: ../data/uuids.csv
# * **SURVEY**: ../data/survey-fake.csv
#
# **If you need to use a different survey file, just modify in the second code cell below this one.**

# %%
import pandas

import util as ut

from util import ESConnection

es_conn = ESConnection()

# %%
# Read survey dataframe from survey and (response id, uuid) correspondence files

############# MODIFY YOUR SURVEY CSV FILE HERE ######################################
survey_df = ut.load_survey_df(survey_filepath='../data/survey-fake.csv',
                              uuids_filepath='../data/uuids.csv')
#####################################################################################

print('Identities with UUID found in survey file: ', len(survey_df))
print('Unique identities found: ', len(survey_df.uuid.unique()))

def add_common_filters(source, s):
    s = s.filter('terms', author_uuid=survey_df['uuid'].tolist())
    # EXCLUDE MOZILLA EMPLOYEES
    s = s.exclude('terms', author_org_name=['Mozilla Staff', 'Code Sheriff', 'Unknown'])
    #print(len(survey_df['uuid'].unique()))

    # Retrieve emails before given year
    #if (source == 'bugzilla'):
    #    s = s.filter('range', creation_ts={'lt': 'now/y'})
    #else:
    #    s = s.filter('range', grimoire_creation_date={'lt': 'now/y'})
        
    return s
# Out:
# Identities with UUID found in survey file:  327
# Unique identities found:  327

# %%
survey_df
# Out:
#                                          uuid  \
# 0    8e750cd848ad5a102edcadd5b3e93c928db87b06
# 1    e911a3c6fb7e95aa13899a09dcbf32ae94095c3d
# 2    7c63ef173f359e3b75e42e10dcec4716eebab452
# 3    046a18bb30a059adf370af956ad52e41f96851b0
# 4    10c7ab6a3b37f0a67bc19c572678a2f8731c621b
# 5    18f5f7c104725182c244c42bd3621756703e0c9c
# 6    c88512a42bbe7d9b1d283adbfd59a45499343583
# 7    02dc242268e8632b3069471be829025be76fed8a
# 8    23f18b9d13fe1cc102c5dff690a6ca2eb2890ba3
# 9    0cd3d032f400e26364e884e768187a99f8d84556
# 10   aa0f0ae660df1027074d82681e9afa1874ea80b3
# 11   04079270cce34cf4360230d1f71c0b0509dc91ac
# 12   32838831a8186961b3fd45b5da2dc2c9f4a4f416
# 13   531daed0a68236d39d6790ed7b80d3cdfeb7dd40
# 14   c42acdcc3691e251b4806275cff7270975a9e19a
# 15   96613cd62253b48cc43780eec4c26c78fd87bb36
# 16   0e9dd5e649d6b8c9d44caaf7f551dd85afa6b4c8
# 17   5d1b85e79d9f104b7ecf8173e7068a7536620069
# 18   4068bb704fccfb719458fe34bdf35a6d1efbf7d4
# 19   08f262271a31f4b9ba739231792db31321b65d48
# 20   45e26f6e9ed0bd483e68034ea72d78eba5006734
# 21   20a244326ac0a7bdf54318a20f7d6f5c2a9af884
# 22   b7d354bd4a362fd1517b9686876e8db6d04ec3a6
# 23   c9fbb3340d507be808bb6272ad72e3d26b002f26
# 29                        Male
# ..                         ...
# 297                       Male
# 298                       Male
# 299                       Male
# 300                       Male
# 301                       Male
# 302                       Male
# 303                       Male
# 304                       Male
# 305                       Male
# 306                       Male
# 307                       Male
# 308                     Female
# 309                       Male
# 310                       Male
# 311                       Male
# 312                       Male
# 313                     Female
# 314                       Male
# 315                       Male
# 316                       Male
# 317                       Male
# 318                     Female
# 319                     Female
# 320                       Male
# 321                       Male
# 322                       Male
# 323                       Male
# 324                       Male
# 325                       Male
# 326                     Female
#
#                                             disability  \
# 0    I wish to voluntarily share that my disability...
# 1                  I am not a person with a disability
# 2                  I am not a person with a disability
# 3                  I am not a person with a disability
# 4
# 5                  I am not a person with a disability
# 6                  I am not a person with a disability
# 7                  I am not a person with a disability
# 8
# 9                  I am not a person with a disability
# 10                 I am not a person with a disability
# 11                 I am not a person with a disability
# 12                 I am not a person with a disability
# 13                 I am not a person with a disability
# 14                 I am not a person with a disability
# 15                 I am not a person with a disability
# 16                 I am not a person with a disability
# 17
# 18
# 19                 I am not a person with a disability
# 20                 I am not a person with a disability
# 21                 I am not a person with a disability
# 22                 I am not a person with a disability
# 23                 I am not a person with a disability
# 24                 I am not a person with a disability
# 25   I wish to voluntarily share that my disability...
# 26                 I am not a person with a disability
# 27                 I am not a person with a disability
# 28                 I am not a person with a disability
# 29                     I am a person with a disability
# ..                                                 ...
# 297                I am not a person with a disability
# 298
# 299                I am not a person with a disability
# 300                I am not a person with a disability
# 301                I am not a person with a disability
# 302                I am not a person with a disability
# 303                I am not a person with a disability
# 304                I am not a person with a disability
# 305                I am not a person with a disability
# 306                I am not a person with a disability
# 307                I am not a person with a disability
# 308                I am not a person with a disability
# 309                I am not a person with a disability
# 310                I am not a person with a disability
# 311                I am not a person with a disability
# 312                I am not a person with a disability
# 313                I am not a person with a disability
# 314                I am not a person with a disability
# 315                I am not a person with a disability
# 316                I am not a person with a disability
# 317                    I am a person with a disability
# 318                I am not a person with a disability
# 319                I am not a person with a disability
# 320                I am not a person with a disability
# 321                I am not a person with a disability
# 322                I am not a person with a disability
# 323                I am not a person with a disability
# 324                I am not a person with a disability
# 325                    I am a person with a disability
# 326                I am not a person with a disability
#
#                        education level                language  \
# 0                    Prefer not to say  Other (please specify)
# 1                    Bachelor’s Degree                 English
# 2                    Bachelor’s Degree  Other (please specify)
# 3                    Bachelor’s Degree                 English
# 4                    Bachelor’s Degree                   Hindi
# 5                    Bachelor’s Degree                 English
# 6                  Postgraduate Degree                 English
# 7                    Bachelor’s Degree  Other (please specify)
# 8                    Bachelor’s Degree                   Hindi
# 9                  Postgraduate Degree                 English
# 10                   Bachelor’s Degree                   Hindi
# 11                 Postgraduate Degree                 English
# 12                   Bachelor’s Degree  Other (please specify)
# 13                   Bachelor’s Degree  Other (please specify)
# 14                   Bachelor’s Degree                 English
# 15                   Bachelor’s Degree                   Hindi
# 16                   Bachelor’s Degree                 English
# 17
# 18   Some College / Associate’s Degree                   Hindi
# 19                   Bachelor’s Degree                 English
# 323         Extremely strong
# 324                   Strong
# 325         Extremely strong  Coding
# 326         Extremely strong
#
# [327 rows x 10 columns]

# %%
### GET AUTHORS IN GIT, THEIR PROJECTS AND COMMITS
source = 'git'
s = ut.create_search(es_conn, source)

s = add_common_filters(source, s)

# Bucketize by uuid and project
s.aggs.bucket('uuid', 'terms', field='author_uuid', size=100000) \
        .bucket('project', 'terms', field='project', size=100000) \
        .metric('commits', 'cardinality', field='hash', precision_threshold=1000000)

result = s.execute()

author_commits_df = ut.stack_by(result=result, group_field='uuid', subgroup_field='project', value_field='commits',
                                group_column='uuid', subgroup_column='git project', value_column='commits')

print('AUTHORS FOUND IN GIT: ', len(author_commits_df['uuid'].unique()))
# Out:
# AUTHORS FOUND IN GIT:  153

# %%
### GET AUTHORS IN BUGZILLA, THEIR PROJECTS AND NUMBER OF BUGS
source = 'bugzilla'
s = ut.create_search(es_conn, source)

s = add_common_filters(source, s)

# Bucketize by uuid and project
s.aggs.bucket('uuid', 'terms', field='author_uuid', size=100000) \
        .bucket('project', 'terms', field='project', size=100000)

result = s.execute()

author_bugs_df = ut.stack_by(result=result, group_field='uuid', subgroup_field='project',
                                group_column='uuid', subgroup_column='bugzilla project', value_column='bugs')

print('AUTHORS FOUND IN BUGZILLA: ', len(author_bugs_df['uuid'].unique()))
# Out:
# AUTHORS FOUND IN BUGZILLA:  177

# %%
### GET AUTHORS IN MAILING LISTS, THEIR PROJECTS AND NUMBER OF EMAILS
source = 'mbox'
s = ut.create_search(es_conn, source)

s = add_common_filters(source, s)

# Bucketize by uuid and project
s.aggs.bucket('uuid', 'terms', field='author_uuid', size=100000) \
        .bucket('project', 'terms', field='project', size=100000)

result = s.execute()

author_emails_df = ut.stack_by(result=result, group_field='uuid', subgroup_field='project',
                                group_column='uuid', subgroup_column='mbox project', value_column='emails')

print('AUTHORS FOUND IN MBOX: ', len(author_emails_df['uuid'].unique()))
# Out:
# AUTHORS FOUND IN MBOX:  122

# %%
### GET AUTHORS IN DISCOURSE, THEIR PROJECTS AND NUMBER OF MESSAGES
source = 'discourse'
s = ut.create_search(es_conn, source)

s = add_common_filters(source,s)

# Bucketize by uuid and project
s.aggs.bucket('uuid', 'terms', field='author_uuid', size=100000) \
        .bucket('project', 'terms', field='project', size=100000)

result = s.execute()

author_discourse_df = ut.stack_by(result=result, group_field='uuid', subgroup_field='project',
                                group_column='uuid', subgroup_column='discourse project', value_column='messages')

print('AUTHORS FOUND IN DISCOURSE: ', len(author_discourse_df['uuid'].unique()))
# Out:
# AUTHORS FOUND IN DISCOURSE:  85

# %%
### GET AUTHORS IN GITHUB, THEIR PROJECTS AND NUMBER OF ISSUES AND PR's
source = 'github_issues'

# PULL REQUESTS
s_prs = ut.create_search(es_conn, source)

s_prs = add_common_filters(source, s_prs)

# Get only PRs
s_prs = s_prs.filter('terms', pull_request=['true'])

s_prs.aggs.bucket('uuid', 'terms', field='author_uuid', size=100000) \
    .bucket('project', 'terms', field='project', size=100)
result_prs = s_prs.execute()


# ISSUES
s_iss = ut.create_search(es_conn, 'github_issues')

s_iss = add_common_filters(source, s_iss)

# Get only Issues
s_iss = s_iss.filter('terms', pull_request=['false'])
s_iss.aggs.bucket('uuid', 'terms', field='author_uuid', size=100000) \
    .bucket('project', 'terms', field='project', size=100)
result_iss = s_iss.execute()


# MERGE PR's and ISSUES

prs_df = ut.stack_by(result=result_prs, group_column='uuid', subgroup_column='github project',
                     value_column='pull requests', group_field='uuid', subgroup_field='project')
iss_df = ut.stack_by(result=result_iss, group_column='uuid', subgroup_column='github project',
                     value_column='issues', group_field='uuid', subgroup_field='project')

github_df = pandas.merge(prs_df, iss_df, how='outer', on=['uuid', 'github project'])
github_df = github_df.fillna(0)

print('AUTHORS FOUND IN GITHUB: ', len(github_df['uuid'].unique()))
# Out:
# AUTHORS FOUND IN GITHUB:  165

# %%
authors_global_df = pandas.concat([author_commits_df, 
                                   author_emails_df, 
                                   github_df, 
                                   author_bugs_df,
                                   author_discourse_df], 
                                  keys=['git', 'mbox', 'github', 'bugzilla', 'discourse'])


grouped_df = authors_global_df.groupby(['uuid']).agg({'emails': 'sum', 
                                                     'commits': 'sum',
                                                     'pull requests': 'sum',
                                                     'issues': 'sum',
                                                     'bugs': 'sum',
                                                     'messages': 'sum',
                                                     'git project': pandas.Series.nunique,
                                                     'mbox project': pandas.Series.nunique,
                                                     'github project': pandas.Series.nunique,
                                                     'bugzilla project': pandas.Series.nunique,
                                                     'discourse project': pandas.Series.nunique
                                                     })

grouped_df = grouped_df.reset_index().sort_values(by=['commits'], ascending=[False])


grouped_df = grouped_df[['uuid', 'commits', 'pull requests', 'issues', 'bugs', 'emails', 'messages',
                         'git project', 'github project', 'bugzilla project', 'mbox project',
                         'discourse project']]

print('AUTHORS FOUND IN GIT, GITHUB, BUGZILLA, MBOX, DISCOURSE: ', len(grouped_df['uuid'].unique()))

grouped_df = grouped_df.fillna(0)
grouped_df
# Out:
# AUTHORS FOUND IN GIT, GITHUB, BUGZILLA, MBOX, DISCOURSE:  269
#                                          uuid  commits  pull requests  issues  \
# 224  9b981479e05cbba272b3d2376a90143e25c0de81   1498.0           29.0   207.0
# 201  78d455c94f2585166eede53d9beb5bca20b7ecdc    892.0          204.0   251.0
# 236  aa0f0ae660df1027074d82681e9afa1874ea80b3    631.0           22.0    15.0
# 219  93a342f7f47d72ebeb9534d06cae0da7008c4bcd    591.0           69.0   232.0
# 89   26bf4956a4120517eaf322d07665984687c24d31    574.0            0.0     5.0
# 6    0257e946520d0e889519cb1a757006efc6202ca9    469.0            1.0     0.0
# 132  464afc233868c436f1ae7ea2470d687067bab5b3    397.0           50.0     2.0
# 187  700ebc9e2e03a453bc0048ebb3f167de6c5195ee    349.0           16.0    65.0
# 34   10e40bc95a121a91b53513dddb255daf512955a8    312.0            0.0     0.0
# 237  ab7d4d184923798a042a6b29eea633c9d52d546b    261.0            0.0     0.0
# 126  42a6c3e779a6333f7aac181508a0f781d7da654a    256.0           22.0     0.0
# 225    1.0    13.0       1.0            0               0                 1
# 226    7.0    67.0       0.0            0               0                 3
# 227    1.0   122.0       0.0            0               0                 1
# 228   13.0     0.0       0.0            0               0                 4
# 231    0.0     0.0       0.0            0               2                 0
# 235    1.0     8.0       0.0            0               0                 1
# 239   14.0     0.0       0.0            0               0                 3
# 242    1.0     0.0      53.0            0               0                 1
# 245    2.0     0.0       0.0            0               0                 2
# 246    0.0     0.0       0.0            0               1                 0
# 249   91.0   175.0      18.0            0               2                 9
# 252    0.0     0.0       0.0            0               1                 0
# 253    0.0     0.0       0.0            0               1                 0
# 254    0.0    18.0      20.0            0               1                 0
# 257   18.0     0.0       0.0            0               0                 3
# 258   33.0     1.0       0.0            0               0                 4
# 259   11.0     0.0       0.0            0               2                 5
# 260    1.0    50.0      15.0            0               0                 1
# 261    0.0     0.0       3.0            0               2                 0
# 262    0.0     0.0       0.0            0               1                 0
# 264    0.0     0.0       0.0            0               1                 0
# 266    0.0     0.0       0.0            0               1                 0
# 268    0.0     0.0       0.0            0               1                 0
#
#      mbox project  discourse project
# 224             7                  4
# 201             0                  0
# 236             3                  0
# 219             4                 10
# 89              2                  0
# 6               0                  1
# 132             2                  0
# 187             1                  3
# 34              1                  0
# 237             1                  0
# 126             0                  0
# 125             0                  0
# 263             6                  8
# 82              6                  7
# 33              1                  0
# 57              6                  1
# 214             0                  0
# 189             3                  0
# 243             0                  0
# 127             2                  2
# 46              2                  0
# 140             3                  4
# 1               0                  0
# 112             2                  2
# 118             1                  0
# 216             5                  2
# 115             0                  2
# 59              8                  5
# 199             3                  0
# 156             1                  0
# ..            ...                ...
# 202             0                  0
# 207             0                  2
# 210             0                  0
# 211             3                  0
# 213             1                  0
# 215             0                  0
# 221             0                  0
# 225             1                  1
# 226             7                  0
# 227             2                  0
# 228             0                  0
# 231             0                  0
# 235             1                  0
# 239             0                  0
# 242             0                  1
# 245             0                  0
# 246             0                  0
# 249             6                  2
# 252             0                  0
# 253             0                  0
# 254             2                  4
# 257             0                  0
# 258             1                  0
# 259             0                  0
# 260             2                  2
# 261             0                  2
# 262             0                  0
# 264             0                  0
# 266             0                  0
# 268             0                  0
#
# [269 rows x 12 columns]

# %%
### USERS WITH NO ACTIVITY OR COLLABORATING IN UNTRACKED PROJECTS
print('Authors matched in Survey: ', len(survey_df.uuid.unique()))
print('Authors found in indexes & projects: ', len(grouped_df.uuid.unique()))
print('\nAuthors matched in survey but being employees or not found in any tracked project:\n')
for element in survey_df.uuid.unique():
    if element not in grouped_df.uuid.unique():
        print(element)
# Out:
# Authors matched in Survey:  327
# Authors found in indexes & projects:  269
#
# Authors matched in survey but being employees or not found in any tracked project:
#
# 531daed0a68236d39d6790ed7b80d3cdfeb7dd40
# 016dd3752addfe79920fcaa2934d0961c510d116
# 5a0d336e645d27220fdf47426e0618776db8f5d7
# 24b889d8fe3052177c78f8ddb5bcc7e95a5b55e7
# 829fa5bd85db080fed69156279859eaa2b43f28c
# 3a78b16f04acf84b7ba14cb07e1040a23dd47bdb
